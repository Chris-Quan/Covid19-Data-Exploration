# %%
import pandas as pd
import sqlite3

# %%
covidDeaths_df= pd.read_csv("data/CovidDeaths.csv")
covidVaccinations_df= pd.read_csv("data/CovidVaccinations.csv")

# %%
covidDeaths_df.head()
# Out:
#   iso_code continent     location      date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  1/3/2020    41128772          NaN
# 1      AFG      Asia  Afghanistan  1/4/2020    41128772          NaN
# 2      AFG      Asia  Afghanistan  1/5/2020    41128772          NaN
# 3      AFG      Asia  Afghanistan  1/6/2020    41128772          NaN
# 4      AFG      Asia  Afghanistan  1/7/2020    41128772          NaN
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        0.0                 NaN           NaN         0.0  ...
# 1        0.0                 NaN           NaN         0.0  ...
# 2        0.0                 NaN           NaN         0.0  ...
# 3        0.0                 NaN           NaN         0.0  ...
# 4        0.0                 NaN           NaN         0.0  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# 1                              NaN                NaN           NaN
# 2                              NaN                NaN           NaN
# 3                              NaN                NaN           NaN
# 4                              NaN                NaN           NaN
#
#    icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# 0                       NaN            NaN                        NaN
# 1                       NaN            NaN                        NaN
# 2                       NaN            NaN                        NaN
# 3                       NaN            NaN                        NaN
# 4                       NaN            NaN                        NaN
#
#    weekly_icu_admissions  weekly_icu_admissions_per_million  \
# 0                    NaN                                NaN
# 1                    NaN                                NaN
# 2                    NaN                                NaN
# 3                    NaN                                NaN
# 4                    NaN                                NaN
#
#    weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 0                     NaN                                 NaN
# 1                     NaN                                 NaN
# 2                     NaN                                 NaN
# 3                     NaN                                 NaN
# 4                     NaN                                 NaN
#
# [5 rows x 26 columns]

# %%
cnn = sqlite3.connect("Covid19-Data.db")

# %%
covidDeaths_df.to_sql("CovidDeaths",cnn)
covidDeaths_df.to_sql("CovidVaccinations",cnn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 covidDeaths_df.to_sql("CovidDeaths",cnn)
#       2 covidDeaths_df.to_sql("CovidVaccinations",cnn)
#
# File d:\Work\anaconda3\lib\site-packages\pandas\core\generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File d:\Work\anaconda3\lib\site-packages\pandas\io\sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File d:\Work\anaconda3\lib\site-packages\pandas\io\sql.py:2187, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2176             raise ValueError(f"{col} ({my_type}) not a string")
#    2178 table = SQLiteTable(
#    2179     name,
#    2180     self,
#    (...)
#    2185     dtype=dtype,
#    2186 )
# -> 2187 table.create()
#    2188 return table.insert(chunksize, method)
#
# File d:\Work\anaconda3\lib\site-packages\pandas\io\sql.py:829, in SQLTable.create(self)
#     827 if self.exists():
#     828     if self.if_exists == "fail":
# --> 829         raise ValueError(f"Table '{self.name}' already exists.")
#     830     elif self.if_exists == "replace":
#     831         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'CovidDeaths' already exists.

# %%
# %load_ext sql

# %%
# %sql sqlite:///Covid19-Data.db
# Out:
# 'Connected: @Covid19-Data.db'

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///Covid19-Data.db
# Done.
# [('CovidDeaths',), ('CovidVaccinations',)]

# %%
# %%sql
#
# SELECT * FROM CovidDeaths LIMIT 10
# Out:
#  * sqlite:///Covid19-Data.db
# Done.
# [(0, 'AFG', 'Asia', 'Afghanistan', '1/3/2020', 41128772, None, 0.0, None, None, 0.0, None, None, 0.0, None, None, 0.0, None, None, None, None, None, None, None, None, None, None),
#  (1, 'AFG', 'Asia', 'Afghanistan', '1/4/2020', 41128772, None, 0.0, None, None, 0.0, None, None, 0.0, None, None, 0.0, None, None, None, None, None, None, None, None, None, None),
#  (2, 'AFG', 'Asia', 'Afghanistan', '1/5/2020', 41128772, None, 0.0, None, None, 0.0, None, None, 0.0, None, None, 0.0, None, None, None, None, None, None, None, None, None, None),
#  (3, 'AFG', 'Asia', 'Afghanistan', '1/6/2020', 41128772, None, 0.0, None, None, 0.0, None, None, 0.0, None, None, 0.0, None, None, None, None, None, None, None, None, None, None),
#  (4, 'AFG', 'Asia', 'Afghanistan', '1/7/2020', 41128772, None, 0.0, None, None, 0.0, None, None, 0.0, None, None, 0.0, None, None, None, None, None, None, None, None, None, None),
#  (5, 'AFG', 'Asia', 'Afghanistan', '1/8/2020', 41128772, None, 0.0, 0.0, None, 0.0, 0.0, None, 0.0, 0.0, None, 0.0, 0.0, None, None, None, None, None, None, None, None, None),
#  (6, 'AFG', 'Asia', 'Afghanistan', '1/9/2020', 41128772, None, 0.0, 0.0, None, 0.0, 0.0, None, 0.0, 0.0, None, 0.0, 0.0, None, None, None, None, None, None, None, None, None),
#  (7, 'AFG', 'Asia', 'Afghanistan', '1/10/2020', 41128772, None, 0.0, 0.0, None, 0.0, 0.0, None, 0.0, 0.0, None, 0.0, 0.0, None, None, None, None, None, None, None, None, None),
#  (8, 'AFG', 'Asia', 'Afghanistan', '1/11/2020', 41128772, None, 0.0, 0.0, None, 0.0, 0.0, None, 0.0, 0.0, None, 0.0, 0.0, None, None, None, None, None, None, None, None, None),
#  (9, 'AFG', 'Asia', 'Afghanistan', '1/12/2020', 41128772, None, 0.0, 0.0, None, 0.0, 0.0, None, 0.0, 0.0, None, 0.0, 0.0, None, None, None, None, None, None, None, None, None)]

# %%
# %%sql
#
# SELECT * FROM data Limit 10
# Out:
#    sqlite:///Covid-Data.db
#  * sqlite:///Covid19-Data.db
#    sqlite:///data.db
# (sqlite3.OperationalError) no such table: data
# [SQL: SELECT * FROM data Limit 10]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# Out:
#    sqlite:///Covid-Data.db
#  * sqlite:///Covid19-Data.db
#    sqlite:///data.db
# (sqlite3.OperationalError) no such table: covid_data
# [SQL: SELECT * from covid_data LIMIT 2]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# Out:
#   Cell In[54], line 1
#     index	iso_code	continent	location	date	total_cases	new_cases	new_cases_smoothed	total_deaths	new_deaths	new_deaths_smoothed	total_cases_per_million	new_cases_per_million	new_cases_smoothed_per_million	total_deaths_per_million	new_deaths_per_million	new_deaths_smoothed_per_million	reproduction_rate	icu_patients	icu_patients_per_million	hosp_patients	hosp_patients_per_million	weekly_icu_admissions	weekly_icu_admissions_per_million	weekly_hosp_admissions	weekly_hosp_admissions_per_million	total_tests	new_tests	total_tests_per_thousand	new_tests_per_thousand	new_tests_smoothed	new_tests_smoothed_per_thousand	positive_rate	tests_per_case	tests_units	total_vaccinations	people_vaccinated	people_fully_vaccinated	total_boosters	new_vaccinations	new_vaccinations_smoothed	total_vaccinations_per_hundred	people_vaccinated_per_hundred	people_fully_vaccinated_per_hundred	total_boosters_per_hundred	new_vaccinations_smoothed_per_million	new_people_vaccinated_smoothed	new_people_vaccinated_smoothed_per_hundred	stringency_index	population_density	median_age	aged_65_older	aged_70_older	gdp_per_capita	extreme_poverty	cardiovasc_death_rate	diabetes_prevalence	female_smokers	male_smokers	handwashing_facilities	hospital_beds_per_thousand	life_expectancy	human_development_index	excess_mortality_cumulative_absolute	excess_mortality_cumulative	excess_mortality	excess_mortality_cumulative_per_million	population	total_cases_new
#          	^
# SyntaxError: invalid syntax
